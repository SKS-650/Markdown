# %% [markdown]
# # Markdown is used almost everywhere in tech:
#
# - Documentation
# - GitHub README files
# - Notes
# - Blogs
# - AI prompts
# - Jupyter notebooks
# - Chat applications
# - Static websites
# - Technical writing
# - Research papers
# - DevOps docs
# - Obsidian/Notion notes
# - Data science reports

# %% [markdown]
# # Markdown Syntax Basics

# %% [markdown]
# # 9. Headings

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4

# %% [markdown]
# # 10. Paragraphs
#
# Simply write text.
#
# This is a paragraph.

# %% [markdown]
# # 11. Line Breaks
#
# Use:
#
# First Line
# Second Line
#
# (Two spaces at the end)
#
# Or leave an empty line.

# %% [markdown]
# # 12. Bold Text
# Syntax
# **Bold**

# %% [markdown]
# # 13. Italic Text
# Syntax
# *Italic*

# %% [markdown]
# # 14. Bold + Italic
# ***Bold Italic***

# %% [markdown]
# # 15. Strikethrough
# ~~Deleted~~

# %% [markdown]
# # 16. Blockquotes
#
# Used for quotes or notes.
#
# > This is a quote

# %% [markdown]
# # 17. Horizontal Line
# ---

# %% [markdown]
# # 18. Ordered Lists
# 1. Apple
# 2. Banana
# 3. Mango

# %% [markdown]
# # 19. Unordered Lists
# - Item
# - Item
# - Item

# %% [markdown]
# # 20. Nested Lists
# - Fruits
#   - Apple
#   - Mango
#     - seasonal
#     - non-seasonal

# %% [markdown]
# # 21. Task Lists
#
# Very useful in projects.
#
# - [x] Learn Markdown
# - [ ] Learn Git

# %% [markdown]
# # 22. Inline Code
# Use `print()` function.

# %% [markdown]
# # 23. Code Blocks
# Syntax
# ```python
# print("Hello")
# ```

# %% [markdown]
# # 24. Syntax Highlighting
#
# Different languages supported:
#
# ```python
# ```javascript
# ```c
# ```java

# %% [markdown]
# # 25. Links
# Syntax
# [Google](https://google.com)

# %% [markdown]
# # 26. Images
# Syntax
# ![Alt Text](image.png)

# %% [markdown]
# # 27. Tables
# Syntax
# | Name | Age |
# |---|---|
# | Shyam | 22 |

# %% [markdown]
# # 28. Alignment in Tables
# | Left | Center | Right |
# |:---|:---:|---:|
# |hello | hi | bye bye |

# %% [markdown]
# # 29. Escaping Characters
#
# Use backslash \
#
# \*not italic\*

# %% [markdown]
# # 30. HTML Inside Markdown
#
# Markdown supports HTML.
#
# <b>Bold</b>

# %% [markdown]
# # 31. Emoji Support
# :smile:
#
# Output may vary by platform.

# %% [markdown]
# # 32. Markdown in GitHub
#
# GitHub heavily uses Markdown.
#
# Important files:
#
# README.md

# %% [markdown]
# # 33. Example README Structure
# # Project Name
#
# ## Installation
#
# ## Features
#
# ## Usage
#
# ## Screenshots
#
# ## License

# %% [markdown]
# # 34. Advanced Markdown
#
# Now entering advanced territory.

# %% [markdown]
# # 35. Footnotes
# Here is a footnote.[^1]
#
# [^1]: Footnote text

# %% [markdown]
# # 36. Checkboxes
#
# Already seen in task lists.
#
# Used in:
#
# - DevOps
# - Agile
# - TODO lists

# %% [markdown]
# # 37. Collapsible Sections
#
# GitHub supports this.
#
# <details>
# <summary>Click Me</summary>
#
# Hidden Content
#
# </details>

# %% [markdown]
# # 38. Mathematical Equations
#
# Supported in some platforms.
#
# Inline:
#
# $E = mc^2$
#
# Block:
#
# $$
# a^2 + b^2 = c^2
# $$

# %% [markdown]
# # 39. Mermaid Diagrams
#
# Very powerful.
#
# graph TD
# A --> B

# %% [markdown]
# # 1. BASIC MARKDOWN EXAMPLE
#
# This example covers:
#
# - Headings
# - Bold
# - Italic
# - Lists
# - Links
# - Images
# - Quotes
# - Code
# - Horizontal line

# %% [markdown]
# # My First Markdown File
#
# Hello everyone.
# Welcome to my Markdown notes.
#
# ---
#
# ## About Me
#
# My name is **Shyam**.
#
# I am learning *Markdown Language*.
#
# ---
#
# ## My Skills
#
# - Python
# - C Programming
# - HTML
# - Machine Learning
#
# ---
#
# ## Daily Routine
#
# 1. Study
# 2. Practice Coding
# 3. Build Projects
#
# ---
#
# ## Inspirational Quote
#
# > Consistency is more important than perfection.
#
# ---
#
# ## Python Example
#
# ```python
# print("Hello Markdown")
# ```
#
# ---
#
# ## Useful Website
#
# [Visit Google](https://google.com)
#
# ---
#
# ## Image Example
#
# ![Python Logo](https://www.python.org/static/community_logos/python-logo.png)

# %% [markdown]
# # 2. INTERMEDIATE MARKDOWN EXAMPLE
#
# This example covers:
#
# - Tables
# - Nested lists
# - Task lists
# - Multiple code blocks
# - Inline code
# - Escaping characters
# - HTML inside Markdown
# - Blockquotes
# - Advanced formatting

# %% [markdown]
# # AI & Machine Learning Study Notes
#
# ---
#
# ## Topics to Learn
#
# - Programming
#   - Python
#   - NumPy
#   - Pandas
#
# - Machine Learning
#   - Supervised Learning
#   - Unsupervised Learning
#   - Reinforcement Learning
#
# - Deep Learning
#   - CNN
#   - RNN
#
# ---
#
# ## Study Checklist
#
# - [x] Learn Python
# - [x] Learn NumPy
# - [ ] Learn Pandas
# - [ ] Learn Machine Learning
#
# ---
#
# ## Student Information
#
# | Name  | Age | Skill |
# |-------|------|--------|
# | Shyam | 22   | Python |
# | Ram   | 21   | C++    |
#
# ---
#
# ## Inline Code Example
#
# Use the `print()` function in Python.
#
# ---
#
# ## Python Program
#
# ```python
# for i in range(5):
#     print(i)
# ```
#
# ---
#
# ## C Program
#
# ```c
# #include <stdio.h>
#
# int main() {
#     printf("Hello");
# }
# ```
#
# ---
#
# ## Important Note
#
# > Practice every day to become better.
#
# ---
#
# ## Escaping Characters
#
# \*This is not italic\*
#
# ---
#
# ## HTML inside Markdown
#
# <b>This text is bold using HTML</b>
#
# <i>This text is italic using HTML</i>
#
# ---
#
# ## Horizontal Line
#
# ---
#
# End of Notes

# %% [markdown]
# # 3. ADVANCED MARKDOWN EXAMPLE
#
# Now let's create a professional-level Markdown document.
#
# This example covers:
#
# - README structure
# - Advanced tables
# - Mermaid diagrams
# - Collapsible sections
# - Footnotes
# - Mathematical equations
# - YAML Front Matter
# - Badges
# - Complex formatting
# - Multi-language code blocks
# - Documentation style

# %% [markdown]
# ---
# title: AI Traffic Management System
# author: Shyam Kishor Sah
# date: 2026-05-29
# ---
#
# # 🚦 AI Traffic Management System
#
# ![Project Banner](https://via.placeholder.com/1000x300)
#
# ---
#
# ## 📌 Project Overview
#
# This project uses:
#
# - Artificial Intelligence
# - Computer Vision
# - YOLOv8
# - IoT Sensors
# - Real-time Analytics
#
# to manage smart city traffic systems.
#
# ---
#
# ## 🚀 Features
#
# - Vehicle Detection
# - Traffic Density Analysis
# - Emergency Vehicle Priority
# - Accident Detection
# - Real-time Monitoring
#
# ---
#
# ## 📂 Project Structure
#
# ```plaintext
# project/
# │
# ├── data/
# ├── models/
# ├── app.py
# ├── requirements.txt
# └── README.md
# ```
#
# ---
#
# ## ⚙️ Installation
#
# ```bash
# git clone https://github.com/project/repo.git
#
# cd project
#
# pip install -r requirements.txt
# ```
#
# ---
#
# ## 🧠 Machine Learning Formula
#
# The loss function:
#
# $$
# Loss = \frac{1}{N} \sum (y - \hat{y})^2
# $$
#
# ---
#
# ## 📊 Accuracy Table
#
# | Model      | Accuracy | Speed |
# |------------|----------|--------|
# | YOLOv8n    | 91%      | Fast   |
# | YOLOv8m    | 95%      | Medium |
# | YOLOv8x    | 98%      | Slow   |
#
# ---
#
# ## ✅ Task Progress
#
# - [x] Dataset Collection
# - [x] Model Training
# - [x] Testing
# - [ ] Deployment
#
# ---
#
# ## 🖼️ Workflow Diagram
#
# ```mermaid
# graph TD
#
# A[Camera Input] --> B[YOLO Detection]
#
# B --> C[Traffic Analysis]
#
# C --> D[Smart Signal Control]
# ```
#
# ---
#
# ## 📌 Important Warning
#
# > High GPU memory is required for large models.
#
# ---
#
# ## 🔒 Collapsible Section
#
# <details>
#
# <summary>Click to Expand</summary>
#
# This section contains hidden details.
#
# - Advanced settings
# - Hyperparameters
# - Debug logs
#
# </details>
#
# ---
#
# ## 💻 Python Example
#
# ```python
# import cv2
#
# camera = cv2.VideoCapture(0)
#
# while True:
#     ret, frame = camera.read()
#     cv2.imshow("Traffic", frame)
#
#     if cv2.waitKey(1) == 27:
#         break
# ```
#
# ---
#
# ## 🌐 API Example
#
# ```json
# {
#     "vehicle_count": 45,
#     "traffic_level": "High"
# }
# ```
#
# ---
#
# ## 📖 Footnotes
#
# AI is transforming transportation systems.[^1]
#
# [^1]: Research Paper on Smart Traffic Systems
#
# ---
#
# ## 🔗 Useful Resources
#
# - [Python](https://python.org)
# - [YOLOv8](https://ultralytics.com)
# - [OpenCV](https://opencv.org)
#
# ---
#
# ## ⭐ Final Conclusion
#
# This project demonstrates:
#
# - AI
# - IoT
# - Real-time systems
# - Smart city automation
#
# working together effectively.
